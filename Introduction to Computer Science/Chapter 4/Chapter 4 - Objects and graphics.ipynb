# %%
# Chapter 4 - Objects and Graphics

# %%
# 4.3 Simple graphics programming

# %%
# Imports the graphics py in the same folder as this program
import graphics

# %%
# Opens the window
win = graphics.GraphWin()

# %%
# Closes the window
win.close()

# %%
# Allows you to load specific definitions from a library module
from graphics import *

# %%
win = GraphWin()

# %%
p = Point(50, 60)
p.getX()
# Out:
# 50.0

# %%
p.getY()
# Out:
# 60.0

# %%
win = GraphWin()
p.draw(win)
p2 = Point(140, 100)
p2.draw(win)
# Out:
# Point(140.0, 100.0)

# %%
win.close()

# %%
# Open a graphics Window
win = GraphWin("Shapes")

# Draw a ref circle centred at point (100,100) with radius 30
center = Point(100, 100)
circ = Circle(center, 30)
circ.setFill("red")
circ.draw(win)

# Put a textual label in the center of the circle
label = Text(center, "Red Circle")
label.draw(win)

# Draw a square using a Rectangle object
rect = Rectangle(Point(30, 30), Point(70, 70))
rect.draw(win)

# Draw a line segment using a Line object
line = Line(Point(20, 30), Point(180, 165))
line.draw(win)

# Draw an oval using the Oval object
oval = Oval(Point(20, 150), Point(180, 199))
oval.draw(win)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0a3febbecbbe> in <module>
#       1 # Open a graphics Window
# ----> 2 win = GraphWin("Shapes")
#       3
#       4 # Draw a ref circle centred at point (100,100) with radius 30
#       5 center = Point(100, 100)
#
# NameError: name 'GraphWin' is not defined

# %%
win.close()

# %%
def main():
    
    # Introduction
    print("This program plots the growth of a 10-year investment.")
    
    # Get principal and interest rate
    principal = float(input("Enter the intial principal: "))
    apr = float(input("Enter the annualized interest rate: "))
    
    # Create a graphics window with labels on left edge
    win = GraphWin("Investment growth chart", 320, 240)
    win.setBackground("white")
    Text(Point(20,230), '0.0k').draw(win)
    Text(Point(20,180), '2.5k').draw(win)
    Text(Point(20,130), '5.0k').draw(win)
    Text(Point(20,80), '7.5k').draw(win)
    Text(Point(20,30), '10.0k').draw(win)
    
    # Draw bar for inital principal
    height = principal * 0.02
    bar = Rectangle(Point(40, 230), Point(65, 230-height))
    bar.setFill("green")
    bar.setWidth(2)
    bar.draw(win)
    
    # Draw bars for successive years
    for year in range(1,11):
        
        # Calculate value for the next year
        principal = principal * (1 + apr)
        
        # Draw bar for this value
        x11 = year * 20 + 40
        height = principal * 0.02
        bar = Rectangle(Point(x11, 230), Point(x11 + 25, 230 - height))
        bar.setFill("green")
        bar.setWidth(2)
        bar.draw(win)
    
    input("Press <Enter> to quit")
    win.close()

main()
# Out:
# This program plots the growth of a 10-year investment.
# Enter the intial principal: 1000
# Enter the annualized interest rate: .10
# Press <Enter> to quit

# %% [markdown]
# #

# %%
# futval_graph2.py

def main():
    
    # Introductions
    print("This program plots the growth of a 10 year investment")
    
    # Get principal and interest rate
    principal = float(input("Enter the initial principal: "))
    apr = float(input("Enter the annualized interest rate: "))
    
    # Create a graphics window with labels on the left edge
    win = GraphWin("Investment Growth Chart", 320, 240)
    win.setBackground("white")
    win.setCoords(-1.75, 200, 11.5, 10400)
    Text(Point(-1,0), '0.0k').draw(win)
    Text(Point(-1,2500), '2.5k').draw(win)
    Text(Point(-1,5000), '5.0k').draw(win)
    Text(Point(-1,7500), '7.5k').draw(win)
    Text(Point(-1,10000), '10.0k').draw(win)
    
    # Draw bar for initial principal
    bar = Rectangle(Point(0, 0), Point(1, principal))
    bar.setFill("green")
    bar.setWidth(2)
    bar.draw(win)
    
    # Draw a bar for each subsequent year
    for year in range (1,11):
        principal = principal * (1 + apr)
        bar = Rectangle(Point(year, 0), Point(year + 1, principal))
        bar.setFill("green")
        bar.setWidth(2)
        bar.draw(win)
        
    input("Press <Enter> to quit.")
    win.close()
    
main()
# Out:
# This program plots the growth of a 10 year investment
# Enter the initial principal: 1000
# Enter the annualized interest rate: 10
# Press <Enter> to quit.

# %%
# click p.y
from graphics import *

def main():
    win = GraphWin("Click Me!")
    for i in range(10):
        p = win.getMouse()
        print("You click at:", p.getX(), p.getY())

main()
# Out:
# You click at: 85.0 100.0
# You click at: 118.0 53.0
# You click at: 55.0 49.0
# You click at: 55.0 115.0
# You click at: 139.0 131.0
# You click at: 149.0 80.0
# You click at: 86.0 81.0
# You click at: 73.0 159.0
# You click at: 20.0 96.0
# You click at: 139.0 57.0

# %%
# tiangle.pyw
from graphics import *

def main():
    win = GraphWin("Draw a Triangle")
    win.setCoords(0.0, 0.0, 10.0, 10.0)
    message = Text(Point(5,0.5), "Click on three points")
    message.draw(win)
    
    # Get and draw three vertices of triangle
    p1 = win.getMouse()
    p1.draw(win)
    p2 = win.getMouse()
    p2.draw(win)
    p3 = win.getMouse()
    p3.draw(win)
    
    # Use Polygon object to draw the triangle
    triangle = Polygon(p1, p2, p3)
    triangle.setFill("peachpuff")
    triangle.setOutline("cyan")
    triangle.draw(win)
    
    # Wait for another click to exit
    message.setText("Click anywhere to quit.")
    win.getMouse()
    
main()

# %%
# 4.7.2 Handling Textual Input

# %%
# clickntype.py

from graphics import *

def main():
    win = GraphWin("Click and type", 400, 400)
    for i in range(10):
        pt = win.getMouse()
        key = win.getKey()
        label = Text(pt, key)
        label.draw(win)
        
main()

# %%
# convert_gui.pyw
# Program to convert Celsius to Farenheit using a simple
# graphical interface

from graphics import *

def main():
    win = GraphWin("Celcius Converter", 400, 300)
    win.setCoords(0.0, 0.0, 3.0, 4.0)
    
    # Draw the interface
    Text(Point(1,3), "  Celcius Temperature:").draw(win)
    Text(Point(1,1), "Fahrenheight Temperature").draw(win)
    inputText = Entry(Point(2.5, 3), 5)
    inputText.setText("0.0")
    inputText.draw(win)
    outputText = Text(Point(2.25, 1),"")
    outputText.draw(win)
    button = Text(Point(1.5,2.0),"Convert It")
    button.draw(win)
    Rectangle(Point(1, 1.5), Point(2, 2.5)).draw(win)
    
    # Wait for a mouse click
    win.getMouse()
    
    # Convert input
    celsius = float(inputText.getText())
    fahrenheit = 9.0/5.0 * celsius + 32
    
    # Display output and change button
    outputText.setText(round(fahrenheit, 2))
    button.setText("Quit")
    
    # Wait for click and then quit
    win.getMouse()
    win.close()

main()
# Out:
# ---------------------------------------------------------------------------
# GraphicsError                             Traceback (most recent call last)
# <ipython-input-1-7733a169618f> in <module>
#      36     win.close()
#      37
# ---> 38 main()
#
# <ipython-input-1-7733a169618f> in main()
#      22
#      23     # Wait for a mouse click
# ---> 24     win.getMouse()
#      25
#      26     # Convert input
#
# ~/Documents/Financial Engineering/Computer science/Introduction to Computer Science/Chapter 4/graphics.py in getMouse(self)
#     314         while self.mouseX == None or self.mouseY == None:
#     315             self.update()
# --> 316             if self.isClosed(): raise GraphicsError("getMouse in closed window")
#     317             time.sleep(.1) # give up thread
#     318         x,y = self.toWorld(self.mouseX, self.mouseY)
#
# GraphicsError: getMouse in closed window

# %%
# Discussion
# 2.

# a.
win = GraphWin()
p = Point(130, 130)
p.draw(win)

# Closes graphics window
win.getMouse()
win.close()

# %%
win.close()

# %%
# b.

win = GraphWin("")

# Draw a ref circle centred at point (30,40) with radius 25
c = Circle(Point (30, 40), 25)
c.setFill("blue")
c.setOutline("red")
c.draw(win)

# Closes graphics window
win.getMouse()
win.close()

# %%
win.close()

# %%
# c.

win = GraphWin("Square")

# Draw a square using a Rectangle object
r = Rectangle(Point(20,20), Point(40,40))
r.setFill(color_rgb(0,255,155))
r.setWidth(3)
r.draw(win)

# Closes graphics window
win.getMouse()
win.close()

# %%
win.close()

# %%
# d.

win = GraphWin("Line")

# Draw a line
l = Line(Point(100,100), Point(100,200))
l.setOutline("red4")
l.setArrow("first")
l.draw(win)

# Closes graphics window
win.getMouse()
win.close()

# %%
# e.

win = GraphWin("Oval")

oval = Oval(Point(50, 50), Point(60, 100))
oval.draw(win)

# Closes graphics window
win.getMouse()
win.close()

# %%
#f.

win = GraphWin("Polygon")

shape = Polygon(Point(5,5), Point(10,10), Point(5,10), Point(10,5))
shape.setFill("orange")
shape.draw(win)

# Closes graphics window
win.getMouse()
win.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-3ac262076661> in <module>
#       8
#       9 # Closes graphics window
# ---> 10 win.getMouse()
#      11 win.close()
#
# ~/Documents/Financial Engineering/Computer science/Introduction to Computer Science/Chapter 4/graphics.py in getMouse(self)
#     315             self.update()
#     316             if self.isClosed(): raise GraphicsError("getMouse in closed window")
# --> 317             time.sleep(.1) # give up thread
#     318         x,y = self.toWorld(self.mouseX, self.mouseY)
#     319         self.mouseX = None
#
# KeyboardInterrupt:

# %%
#g.

win = GraphWin("Polygon")

t = Text(Point(100,100), "Hello world!")
t.setFace("courier")
t.setSize(16)
t.setStyle("italic")
t.draw(win)

# Closes graphics window
win.getMouse()
win.close()

# %%
# 3.

from graphics import *

def main():
    win = GraphWin()
    
    # Draws a circle and fills it in red
    
    shape = Circle(Point(50,50),20)
    shape.setOutline("red")
    shape.setFill("red")
    shape.draw(win)
    
    # Click anywhere for the square to move
    
    # Function will only run 10 times
    for i in range(10):
        
        # Pauses for the user to click a mouse in the window
        p = win.getMouse()
        
        # Returns the center point of the circle
        c = shape.getCenter()
        
        # returns the x point on variable p minus the x point in 
        # variable c
        dx = p.getX() - c.getX()
        
         # returns the y point on variable p minus the y point in 
        # variable c
        dy = p.getY() - c.getY()
        
        # Moves the image to the adjusted position
        shape.move(dx,dy)
    
    # closes the window
    win.close()
main()

# %%
# Programming exercises
# 1
# a/. - c/.

# Incorrect code - please see below

from graphics import *

def main():
    win = GraphWin()
    
    # Draws a Square and fills it in red
    
    shape = Rectangle(Point(20,20), Point(60,60))
    shape.setOutline("red")
    shape.setFill("red")
    shape.draw(win)
    
    # Click anywhere for the square to move
    
    # Function will only run 10 times
    for i in range(10):
        
        # Pauses for the user to click a mouse in the window
        p = win.getMouse()
        
        # Returns the center point of the shape
        c = shape.getCenter()
        
        # returns the x point on variable p minus the x point in 
        # variable c
        dx = p.getX() - c.getX()
        
         # returns the y point on variable p minus the y point in 
        # variable c
        dy = p.getY() - c.getY()
        
        # Moves the image to the adjusted position
        shape.move(dx,dy)
    
    # closes the window
    message = Text(Point(5,0.5), "Click again to quit")
    message.draw(win)
    win.close()

main()

# %%
# Programming exercises
# 1 - Answer
# a/. - c/.

from graphics import *

def main():
    win = GraphWin("Draw a Rectangle")
    
    # Draws a Square and fills it in red
    
    shape = Rectangle(Point(30,30), Point(70,70))
    shape.setOutline("red")
    shape.setFill("red")
    shape.draw(win)
    
    # Click anywhere for the square to move
    
    # Function will only run 10 times
    for i in range(10):
        
        # Pauses for the user to click a mouse in the window
        p = win.getMouse()
        
        # Returns the center point of the shape
        c = shape.getCenter()
        
        # returns the x point on variable p minus the x point in 
        # variable c
        dx = p.getX() - c.getX()
        
         # returns the y point on variable p minus the y point in 
        # variable c
        dy = p.getY() - c.getY()
        
        # Change variable name and returns a druplicate of the object
        shape2 = shape.clone()
        
        # Moves the image to the adjusted position
        shape2.move(dx,dy)
        
        # Draws the object
        shape2.draw(win)
    
    # Adds a message at the end
    message = Text(Point(100,10), "Click again to quit")
    message.draw(win)
    
    # Pauses for the user to click a mouse in the window
    win.getMouse()
    win.close()

main()

# %%
# 2.

# Draw a Target range
# 1 Central ring that is yellow
# Surrounded by rings of red,white then black.
# All rings have the same width of the yellow

from graphics import *

def main():
    win = GraphWin("Target range")
    
    # Draw first ring 
    red_circle = Circle(Point(100,100),100)
    red_circle.setOutline("red")
    red_circle.setFill("red")
    red_circle.draw(win)
    
    
    # Draw second ring
    white_circle = Circle(Point(100,100),80)
    white_circle.setOutline("white")
    white_circle.setFill("white")
    white_circle.draw(win)
    
    
    # Draw third ring
    black_circle = Circle(Point(100,100),60)
    black_circle.setOutline("black")
    black_circle.setFill("black")
    black_circle.draw(win)
    
    
    # Draw 4th ring
    white_circle1 = Circle(Point(100,100),40)
    white_circle1.setOutline("white")
    white_circle1.setFill("white")
    white_circle1.draw(win)
    
    
    # Draw 5th ring
    yellow_circle = Circle(Point(100,100),20)
    yellow_circle.setOutline("yellow")
    yellow_circle.setFill("yellow")
    yellow_circle.draw(win)
    
    # Closes graphics window
    win.getMouse()
    win.close()
    
main()

# %%
# 3.
# Draw a face with one eye =)

from graphics import *

def main():
    win = GraphWin("Face")
    win.setBackground("white")
    
    # Draw the face
    outline = Circle(Point(100,100),50)
    outline.draw(win)
    leftEye = Circle(Point(77,80),5)
    leftEye.setFill("black")
    leftEye.draw(win)
    rightEye = leftEye.clone()
    rightEye.move(123,80)
    rightEye.draw(win)
    nose = Line(Point(100,90), Point(100,110))
    nose.draw(win)
    mouth = Polygon(Point(70,120), Point(130,120), Point(115,130))
    mouth.setFill("black")
    mouth.draw(win)
    
    # Closes graphics window by clicking the mouse
    win.getMouse()
    win.close()

main()

# %% [markdown]
# 4.

# %%
# 4.
# Write a program that draws a winter scene with a christmas tree
# and a snowman

# 3 circles for the structure of the snowman
# Small circles for eyes,nose teeth and buttons of the of the
# snow man that are filled in black
# Rectangle for base of tree
# Lines to create structure of the christmas tree

from graphics import *

def main():
    # Create the 200 by 200 pixel window
    win = GraphWin("Winter Paradise")
    
    # Drawing the snowman structure
    bottom_body = Circle(Point(60,140),40)
    bottom_body.setOutline("black")
    bottom_body.setFill("white")
    bottom_body.draw(win)
    middle_body = Circle(Point(60,70),30)
    middle_body.setOutline("black")
    middle_body.setFill("white")
    middle_body.draw(win)
    head = Circle(Point(60,20),20)
    head.setOutline("black")
    head.setFill("white")
    head.draw(win)
    
    # Snowman Face details
    leftEye = Circle(Point(50,15),4)
    leftEye.setFill("black")
    leftEye.draw(win)
    rightEye = Circle(Point(70,15),4)
    rightEye.setFill("black")
    rightEye.draw(win)
    teeth1 = Rectangle(Point(60,30),Point(60,31))
    teeth1.setFill("black")
    teeth1.draw(win)
    teeth2 = Rectangle(Point(57,29),Point(57,30))
    teeth2.setFill("black")
    teeth2.draw(win)
    teeth3 = Rectangle(Point(63,29),Point(63,30))
    teeth3.setFill("black")
    teeth3.draw(win)
    
    # Snowman body
    button1 = Rectangle(Point(60,60),Point(62,62))
    button1.setFill("black")
    button1.draw(win)
    button2 = Rectangle(Point(60,64),Point(62,66))
    button2.setFill("black")
    button2.draw(win)
    button3 = Rectangle(Point(60,68),Point(62,70))
    button3.setFill("black")
    button3.draw(win)
    button4 = Rectangle(Point(60,72),Point(62,74))
    button4.setFill("black")
    button4.draw(win)
    button5 = Rectangle(Point(60,76),Point(62,78))
    button5.setFill("black")
    button5.draw(win)
    rightarm = Line(Point(90, 65), Point(110, 70))
    rightarm.draw(win)
    rightfinger1 = Line(Point(103, 69), Point(110, 75))
    rightfinger1.draw(win)
    rightfinger2 = Line(Point(103, 69), Point(110, 63))
    rightfinger2.draw(win)
    leftarm = Line(Point(30, 65), Point(10, 70))
    leftarm.draw(win)
    leftfinger1 = Line(Point(17, 69), Point(10, 75))
    leftfinger1.draw(win)
    leftfinger2 = Line(Point(17, 69), Point(10, 63))
    leftfinger2.draw(win)

    
    # Christmas tree
    shape = Rectangle(Point(140,140), Point(160,175))
    shape.setOutline("brown")
    shape.setFill("brown")
    shape.draw(win)
    branch1 = Polygon(Point(105,140), Point(150,100), Point(195,140))
    branch1.setOutline("green")
    branch1.setFill("green")
    branch1.draw(win)
    branch2 = Polygon(Point(115,110), Point(150,70), Point(185,110))
    branch2.setOutline("green")
    branch2.setFill("green")
    branch2.draw(win)
    branch3 = Polygon(Point(125,80), Point(150,40), Point(175,80))
    branch3.setOutline("green")
    branch3.setFill("green")
    branch3.draw(win)
    
    
    # Christmas tree ornaments
    ornament1 = Circle(Point(140,70),3)
    ornament1.setFill("red")
    ornament1.draw(win)
    ornament2 = Circle(Point(160,70),3)
    ornament2.setFill("blue")
    ornament2.draw(win)
    ornament3 = Circle(Point(130,100),3)
    ornament3.setFill("yellow")
    ornament3.draw(win)
    ornament4 = Circle(Point(150,100),3)
    ornament4.setFill("red")
    ornament4.draw(win)
    ornament5 = Circle(Point(170,100),3)
    ornament5.setFill("white")
    ornament5.draw(win)
    ornament6 = Circle(Point(120,133),3)
    ornament6.setFill("yellow")
    ornament6.draw(win)
    ornament7 = Circle(Point(140,133),3)
    ornament7.setFill("red")
    ornament7.draw(win)
    ornament8 = Circle(Point(160,133),3)
    ornament8.setFill("white")
    ornament8.draw(win)
    ornament9 = Circle(Point(180,133),3)
    ornament9.setFill("white")
    ornament9.draw(win)
    
    # Closes the graphics window by clicking the mouse
    win.getMouse()
    win.close()
    
main()
# Out:
# ---------------------------------------------------------------------------
# GraphicsError                             Traceback (most recent call last)
# <ipython-input-6-80eeda4b7fca> in <module>
#     128     win.close()
#     129
# --> 130 main()
#
# <ipython-input-6-80eeda4b7fca> in main()
#     125
#     126     # Closes the graphics window by clicking the mouse
# --> 127     win.getMouse()
#     128     win.close()
#     129
#
# ~/Documents/Financial Engineering/Computer science/Introduction to Computer Science/Chapter 4/graphics.py in getMouse(self)
#     314         while self.mouseX == None or self.mouseY == None:
#     315             self.update()
# --> 316             if self.isClosed(): raise GraphicsError("getMouse in closed window")
#     317             time.sleep(.1) # give up thread
#     318         x,y = self.toWorld(self.mouseX, self.mouseY)
#
# GraphicsError: getMouse in closed window

# %%
# 5.
# Write a program that draws 5 dice on the screen depicting a 
# straight (1, 2 ,3 ,4 ,5, 6 or 2, 3, 4, 5, 6).

# 6 squares
# small squares inside these squares to depict the number on dice

# %%
from graphics import *

def main():
    # Create the 200 by 200 pixel window
    win = GraphWin("Dice")

    # Dice 1
    Dice1 = Rectangle(Point(40,50), Point(75,85))
    Dice1.setFill("white")
    Dice1.draw(win)
    button1 = Rectangle(Point(56,66),Point(58,68))
    button1.setFill("black")
    button1.draw(win)
    
    
    # Dice 2
    Dice2 = Rectangle(Point(90,50), Point(125,85))
    Dice2.setFill("white")
    Dice2.draw(win)
    button2 = Rectangle(Point(97,58),Point(99,60))
    button2.setFill("black")
    button2.draw(win)
    button3 = Rectangle(Point(116,77),Point(118,79))
    button3.setFill("black")
    button3.draw(win)
    
    # Dice 3
    Dice3 = Rectangle(Point(140,50), Point(175,85))
    Dice3.setFill("white")
    Dice3.draw(win)
    button4 = Rectangle(Point(147,58),Point(149,60))
    button4.setFill("black")
    button4.draw(win)
    button5 = Rectangle(Point(156,67),Point(158,69))
    button5.setFill("black")
    button5.draw(win)
    button6 = Rectangle(Point(166,77),Point(168,79))
    button6.setFill("black")
    button6.draw(win)
    
    # Dice 4
    Dice4 = Rectangle(Point(40,100), Point(75,135))
    Dice4.setFill("white")
    Dice4.draw(win)
    button7 = Rectangle(Point(47,108),Point(49,110))
    button7.setFill("black")
    button7.draw(win)
    button8 = Rectangle(Point(66,108),Point(68,110))
    button8.setFill("black")
    button8.draw(win)
    button9 = Rectangle(Point(47,127),Point(49,129))
    button9.setFill("black")
    button9.draw(win)
    button10 = Rectangle(Point(66,127),Point(68,129))
    button10.setFill("black")
    button10.draw(win)
    
    # Dice 5
    Dice5 = Rectangle(Point(90,100), Point(125,135))
    Dice5.setFill("white")
    Dice5.draw(win)
    button11 = Rectangle(Point(97,108),Point(99,110))
    button11.setFill("black")
    button11.draw(win)
    button12 = Rectangle(Point(116,108),Point(118,110))
    button12.setFill("black")
    button12.draw(win)
    button13 = Rectangle(Point(107,118),Point(109,120))
    button13.setFill("black")
    button13.draw(win)
    button14 = Rectangle(Point(97,127),Point(99,129))
    button14.setFill("black")
    button14.draw(win)
    button15 = Rectangle(Point(116,127),Point(118,129))
    button15.setFill("black")
    button15.draw(win)
    
    # Dice 6
    Dice6 = Rectangle(Point(140,100), Point(175,135))
    Dice6.setFill("white")
    Dice6.draw(win)
    button16 = Rectangle(Point(147,108),Point(149,110))
    button16.setFill("black")
    button16.draw(win)
    button17 = Rectangle(Point(166,108),Point(168,110))
    button17.setFill("black")
    button17.draw(win)
    button18 = Rectangle(Point(147,117),Point(149,119))
    button18.setFill("black")
    button18.draw(win)
    button19 = Rectangle(Point(166,117),Point(168,119))
    button19.setFill("black")
    button19.draw(win)
    button20 = Rectangle(Point(147,127),Point(149,129))
    button20.setFill("black")
    button20.draw(win)
    button21 = Rectangle(Point(166,127),Point(168,129))
    button21.setFill("black")
    button21.draw(win)
    
    
    # Closes the graphics window by clicking the mouse
    win.getMouse()
    win.close()
    
main()

# %%
# 6.
# Modify the graphical future value program so that the input
# (Principal and APR) also are done in a graphical fashion using
# Entry objects.

# %%
from graphics import *

def main():
    
    # Introduction
    print("This program plots the growth of a 10-year investment.")
    
    # Create a graphics window
    win= GraphWin("Investment Growth Chart", 320, 240)
    win.setBackground("white")
    win.setCoords(-2, -700, 11.3, 14000)
    
        # win.setCoords(x11, y11, xur, yur)
        # sets the coordinate system of the window 
        # The lower left corner is (x11,y11) and the upper right corner
        # is (xur, yur). Currently drawn objects are redrawn and 
        # subsequent drawing is done with respect to the new
        # coordinate system (except for plotPixel).
        # Example: win.setCoords(0, 0, 200, 100)
    
    # Creates labels on the left edge
    Text(Point(-1,0), " 0.0K").draw(win)
    Text(Point(-1,2500), " 2.5K").draw(win)
    Text(Point(-1,5000), " 5.0K").draw(win)
    Text(Point(-1,7500), " 7.5K").draw(win)
    Text(Point(-1,10000), " 10.0K").draw(win)
    
    # Create the principal and apr Entry objects along with some Text
    Text(Point(0,12500), "Principal: ").draw(win)
    Text(Point(7,12500), "APR: ").draw(win)
    prin_input = Entry(Point(3.5, 12500), 10).draw(win)
    apr_input = Entry(Point(9,12500), 5).draw(win)
    
    # Wait for a mouse click
    win.getMouse()
    
    # Conversions
    principal = eval(prin_input.getText())
    apr = eval(apr_input.getText())
    
    # Draw bar for inital principal
    bar = Rectangle(Point(0, 0), Point(1, principal))
    bar.setFill("green")
    bar.setWidth(2)
    bar.draw(win)
    
    # Draw bars for successive years
    for year in range(1,11):
        principal = principal * (1 + apr)
        bar = Rectangle(Point(year, 0), Point(year+1, principal))
        bar.setFill("green")
        bar.setWidth(2)
        bar.draw(win)
          
    # Closes the graphics window by clicking the mouse
    win.getMouse()
    win.close()
    
main()
# Out:
# This program plots the growth of a 10-year investment.
# Press <Enter> to quit

# %%
# 7.
# Write a program that computes the intersection of a circle with a
# horizontal line and displays the information textually and graphically.

# Input: Radius of the circle and the y-intercept of the line.
# Output: Draw a circle centered at (0,0) with the given radius in a window
# with coordinates running from -10,-10 to 10,10.

# Draw a hirozntal line across the windown the the given y-intercept.
# Draw the two points of intersection in red.

# Print out the x values of the points of intersection.

# Forumula: x = +- (R**2-r**y) * .05

# %%
from graphics import *

def main():
    
    # Introduction
    print("This program plots a cirle with a horizontal line intersection.")
    
    # Create a graphics window with labels on the left edge
    win= GraphWin("Investment Growth Chart", 320, 240)
    win.setBackground("white")
    win.setCoords(-2, -700, 11.3, 14000)
    Text(Point(-1,0), " 0.0K").draw(win)
    Text(Point(-1,2500), " 2.5K").draw(win)
    Text(Point(-1,5000), " 5.0K").draw(win)
    Text(Point(-1,7500), " 7.5K").draw(win)
    Text(Point(-1,10000), " 10.0K").draw(win)
    
    # Create the principal and apr Entry objects along with some Text
    Text(Point(0,12500), "Principal: ").draw(win)
    Text(Point(7,12500), "APR: ").draw(win)
    prin_input = Entry(Point(3.5, 12500), 10).draw(win)
    apr_input = Entry(Point(9,12500), 5).draw(win)
    
    # Wait for a mouse click
    win.getMouse()
    
    # Conversions
    principal = eval(prin_input.getText())
    apr = eval(apr_input.getText())
    
    # Draw bar for inital principal
    bar = Rectangle(Point(0, 0), Point(1, principal))
    bar.setFill("green")
    bar.setWidth(2)
    bar.draw(win)
    
    # Draw bars for successive years
    for year in range(1,11):
        principal = principal * (1 + apr)
        bar = Rectangle(Point(year, 0), Point(year+1, principal))
        bar.setFill("green")
        bar.setWidth(2)
        bar.draw(win)
          
    input("Press <Enter> to quit")
    win.close()
    
main()
